# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Preprocessing

# %%
#Import data set and separate columns at ;
train = pd.read_csv("train.csv", delimiter = ';')
test = pd.read_csv("test.csv", delimiter = ';')

# %%
# Concatenate the two dataframes vertically (along rows)
Banking_data = pd.concat([train, test], ignore_index=True)

# %%
#Get cloumns names
Banking_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
#check for null values
Banking_data.isnull().sum().sort_values(ascending=False)
# Out:
# age          0
# day          0
# poutcome     0
# previous     0
# pdays        0
# campaign     0
# duration     0
# month        0
# contact      0
# job          0
# loan         0
# housing      0
# balance      0
# default      0
# education    0
# marital      0
# y            0
# dtype: int64

# %%
#Get the shape of the DataFrame
Banking_data.shape
# Out:
# (49732, 17)

# %%
# Save the merged dataframe to a new CSV file
Banking_data.to_csv("Banking_data.csv", index=False)

# %%
df = pd.read_csv("Banking_data.csv")

# %%
df
# Out:
#        age            job  marital  education default  balance housing loan  \
# 0       58     management  married   tertiary      no     2143     yes   no
# 1       44     technician   single  secondary      no       29     yes   no
# 2       33   entrepreneur  married  secondary      no        2     yes  yes
# 3       47    blue-collar  married    unknown      no     1506     yes   no
# 4       33        unknown   single    unknown      no        1      no   no
# ...    ...            ...      ...        ...     ...      ...     ...  ...
# 49727   33       services  married  secondary      no     -333     yes   no
# 49728   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 49729   57     technician  married  secondary      no      295      no   no
# 49730   28    blue-collar  married  secondary      no     1137      no   no
# 49731   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome   y
# 0       unknown    5   may       261         1     -1         0  unknown  no
# 1       unknown    5   may       151         1     -1         0  unknown  no
# 2       unknown    5   may        76         1     -1         0  unknown  no
# 3       unknown    5   may        92         1     -1         0  unknown  no
# 4       unknown    5   may       198         1     -1         0  unknown  no
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ..
# 49727  cellular   30   jul       329         5     -1         0  unknown  no
# 49728   unknown    9   may       153         1     -1         0  unknown  no
# 49729  cellular   19   aug       151        11     -1         0  unknown  no
# 49730  cellular    6   feb       129         4    211         3    other  no
# 49731  cellular    3   apr       345         2    249         7    other  no
#
# [49732 rows x 17 columns]

# %%
#Get uniques values
job = df.job.unique()
month = df.month.unique()
marital = df.marital.unique()
education = df.education.unique()
contact = df.contact.unique()
poutcome = df.poutcome.unique()

print(job)
print()
print(month)
print()
print(marital)
print()
print(education)
print()
print(contact)
print()
print(poutcome)
# Out:
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# ['married' 'single' 'divorced']
#
# ['tertiary' 'secondary' 'unknown' 'primary']
#
# ['unknown' 'cellular' 'telephone']
#
# ['unknown' 'failure' 'other' 'success']

# %%
#Change prediction column name
df.rename(columns = {'y':'FDcreated'}, inplace=True)

# %% [markdown]
# Encoding

# %%
#change yes = 1 no = 0
df['default'] = df['default'].map({'yes': 1, 'no':0})
df['housing'] = df['housing'].map({'yes': 1, 'no':0})
df['loan'] = df['loan'].map({'yes': 1, 'no':0})
df['FDcreated'] = df['FDcreated'].map({'yes': 1, 'no':0})

#Give values for each attribute
df['marital'] = df['marital'].map({'married': 1, 'single':2, 'divorced':3})
df['education'] = df['education'].map({'unknown':np.nan, 'tertiary': 1, 'secondary':2,'primary':3})
df['job'] = df['job'].map({'unknown':np.nan ,'admin': 1,'unemployed':2, 'management':3, 'housemaid':4, 'entrepreneur':5, 'student':6, 'blue-collar':7, 'self-employed':8, 'retired':9, 'technician':10, 'services':11})
df['contact'] = df['contact'].map({'unknown': np.nan, 'cellular':1, 'telephone':2})
df['month'] = df['month'].map({'jan': 1, 'feb':2 ,'mar':3, 'apr':4, 'may':5, 'jun':6, 'jul':7, 'aug':8, 'sep':9, 'oct':10, 'nov':11, 'dec':12})
df['poutcome'] = df['poutcome'].map({'unknown': np.nan, 'failure':1, 'other':2, 'success':3})


df
# Out:
#        age   job  marital  education  default  balance  housing  loan  \
# 0       58   3.0        1        1.0        0     2143        1     0
# 1       44  10.0        2        2.0        0       29        1     0
# 2       33   5.0        1        2.0        0        2        1     1
# 3       47   7.0        1        NaN        0     1506        1     0
# 4       33   NaN        2        NaN        0        1        0     0
# ...    ...   ...      ...        ...      ...      ...      ...   ...
# 49727   33  11.0        1        2.0        0     -333        1     0
# 49728   57   8.0        1        1.0        1    -3313        1     1
# 49729   57  10.0        1        2.0        0      295        0     0
# 49730   28   7.0        1        2.0        0     1137        0     0
# 49731   44   5.0        2        1.0        0     1136        1     1
#
#        contact  day  month  duration  campaign  pdays  previous  poutcome  \
# 0          NaN    5      5       261         1     -1         0       NaN
# 1          NaN    5      5       151         1     -1         0       NaN
# 2          NaN    5      5        76         1     -1         0       NaN
# 3          NaN    5      5        92         1     -1         0       NaN
# 4          NaN    5      5       198         1     -1         0       NaN
# ...        ...  ...    ...       ...       ...    ...       ...       ...
# 49727      1.0   30      7       329         5     -1         0       NaN
# 49728      NaN    9      5       153         1     -1         0       NaN
# 49729      1.0   19      8       151        11     -1         0       NaN
# 49730      1.0    6      2       129         4    211         3       2.0
# 49731      1.0    3      4       345         2    249         7       2.0
#
#        FDcreated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 49727          0
# 49728          0
# 49729          0
# 49730          0
# 49731          0
#
# [49732 rows x 17 columns]

# %% [markdown]
# Normalization

# %%
#Balance
minB = df['balance'].min()
maxB = df['balance'].max()

print("Minimum balance: ", minB)
print("Maximum balance: ", maxB)

df['balance'] = df['balance'].apply(lambda v: (v - df['balance'].min())/ (df['balance'].max() - df['balance'].min()))

df
# Out:
# Minimum balance:  -8019
# Maximum balance:  102127
#        age   job  marital  education  default   balance  housing  loan  \
# 0       58   3.0        1        1.0        0  0.092259        1     0
# 1       44  10.0        2        2.0        0  0.073067        1     0
# 2       33   5.0        1        2.0        0  0.072822        1     1
# 3       47   7.0        1        NaN        0  0.086476        1     0
# 4       33   NaN        2        NaN        0  0.072812        0     0
# ...    ...   ...      ...        ...      ...       ...      ...   ...
# 49727   33  11.0        1        2.0        0  0.069780        1     0
# 49728   57   8.0        1        1.0        1  0.042725        1     1
# 49729   57  10.0        1        2.0        0  0.075482        0     0
# 49730   28   7.0        1        2.0        0  0.083126        0     0
# 49731   44   5.0        2        1.0        0  0.083117        1     1
#
#        contact  day  month  duration  campaign  pdays  previous  poutcome  \
# 0          NaN    5      5       261         1     -1         0       NaN
# 1          NaN    5      5       151         1     -1         0       NaN
# 2          NaN    5      5        76         1     -1         0       NaN
# 3          NaN    5      5        92         1     -1         0       NaN
# 4          NaN    5      5       198         1     -1         0       NaN
# ...        ...  ...    ...       ...       ...    ...       ...       ...
# 49727      1.0   30      7       329         5     -1         0       NaN
# 49728      NaN    9      5       153         1     -1         0       NaN
# 49729      1.0   19      8       151        11     -1         0       NaN
# 49730      1.0    6      2       129         4    211         3       2.0
# 49731      1.0    3      4       345         2    249         7       2.0
#
#        FDcreated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 49727          0
# 49728          0
# 49729          0
# 49730          0
# 49731          0
#
# [49732 rows x 17 columns]

# %%
#pdays
minPD = df['pdays'].min()
maxPD = df['pdays'].max()

print("Minimum pdays: ", minPD)
print("Maximum pdays: ", maxPD)

df['pdays'] = df['pdays'].apply(lambda v: (v - df['pdays'].min())/ (df['pdays'].max() - df['pdays'].min()))

df
# Out:
# Minimum pdays:  -1
# Maximum pdays:  871
#        age   job  marital  education  default   balance  housing  loan  \
# 0       58   3.0        1        1.0        0  0.092259        1     0
# 1       44  10.0        2        2.0        0  0.073067        1     0
# 2       33   5.0        1        2.0        0  0.072822        1     1
# 3       47   7.0        1        NaN        0  0.086476        1     0
# 4       33   NaN        2        NaN        0  0.072812        0     0
# ...    ...   ...      ...        ...      ...       ...      ...   ...
# 49727   33  11.0        1        2.0        0  0.069780        1     0
# 49728   57   8.0        1        1.0        1  0.042725        1     1
# 49729   57  10.0        1        2.0        0  0.075482        0     0
# 49730   28   7.0        1        2.0        0  0.083126        0     0
# 49731   44   5.0        2        1.0        0  0.083117        1     1
#
#        contact  day  month  duration  campaign     pdays  previous  poutcome  \
# 0          NaN    5      5       261         1  0.000000         0       NaN
# 1          NaN    5      5       151         1  0.000000         0       NaN
# 2          NaN    5      5        76         1  0.000000         0       NaN
# 3          NaN    5      5        92         1  0.000000         0       NaN
# 4          NaN    5      5       198         1  0.000000         0       NaN
# ...        ...  ...    ...       ...       ...       ...       ...       ...
# 49727      1.0   30      7       329         5  0.000000         0       NaN
# 49728      NaN    9      5       153         1  0.000000         0       NaN
# 49729      1.0   19      8       151        11  0.000000         0       NaN
# 49730      1.0    6      2       129         4  0.243119         3       2.0
# 49731      1.0    3      4       345         2  0.286697         7       2.0
#
#        FDcreated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 49727          0
# 49728          0
# 49729          0
# 49730          0
# 49731          0
#
# [49732 rows x 17 columns]

# %%
#get the counts without NaN values
df.describe()
# Out:
#                 age           job       marital     education       default  \
# count  49732.000000  43757.000000  49732.000000  47688.000000  49732.000000
# mean      40.957472      6.837237      1.511864      1.850654      0.017916
# std       10.615008      2.952440      0.693185      0.665441      0.132648
# min       18.000000      2.000000      1.000000      1.000000      0.000000
# 25%       33.000000      3.000000      1.000000      1.000000      0.000000
# 50%       39.000000      7.000000      1.000000      2.000000      0.000000
# 75%       48.000000     10.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      3.000000      3.000000      1.000000
#
#             balance       housing          loan       contact           day  \
# count  49732.000000  49732.000000  49732.000000  35388.000000  49732.000000
# mean       0.085221      0.556764      0.159555      1.090624     15.816315
# std        0.027614      0.496772      0.366197      0.287078      8.315680
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%        0.073457      0.000000      0.000000      1.000000      8.000000
# 50%        0.076871      1.000000      0.000000      1.000000     16.000000
# 75%        0.085795      1.000000      0.000000      1.000000     21.000000
# max        1.000000      1.000000      1.000000      2.000000     31.000000
#
#               month      duration      campaign         pdays      previous  \
# count  49732.000000  49732.000000  49732.000000  49732.000000  49732.000000
# mean       6.146666    258.690179      2.766549      0.047200      0.576892
# std        2.405338    257.743149      3.099075      0.114825      2.254838
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        5.000000    103.000000      1.000000      0.000000      0.000000
# 50%        6.000000    180.000000      2.000000      0.000000      0.000000
# 75%        8.000000    320.000000      3.000000      0.000000      0.000000
# max       12.000000   4918.000000     63.000000      1.000000    275.000000
#
#           poutcome     FDcreated
# count  9068.000000  49732.000000
# mean      1.586348      0.116826
# std       0.777382      0.321216
# min       1.000000      0.000000
# 25%       1.000000      0.000000
# 50%       1.000000      0.000000
# 75%       2.000000      0.000000
# max       3.000000      1.000000

# %%
#find the correlation between attributes and target varibel(FDCreated)
df.corr()
# Out:
#                 age       job   marital  education   default   balance  \
# age        1.000000  0.022420 -0.126154   0.169024 -0.017895  0.096564
# job        0.022420  1.000000  0.006253   0.308947 -0.005018 -0.059361
# marital   -0.126154  0.006253  1.000000  -0.102812  0.021197 -0.028258
# education  0.169024  0.308947 -0.102812   1.000000  0.011829 -0.068171
# default   -0.017895 -0.005018  0.021197   0.011829  1.000000 -0.067118
# balance    0.096564 -0.059361 -0.028258  -0.068171 -0.067118  1.000000
# housing   -0.186225  0.069373 -0.013138   0.078523 -0.004906 -0.067068
# loan      -0.015299  0.054872 -0.018112   0.027624  0.076101 -0.083231
# contact    0.193826  0.015309 -0.051503   0.112556 -0.018047  0.036429
# day       -0.009880 -0.000567 -0.004975  -0.025722  0.007432  0.003348
# month      0.091204 -0.041774 -0.042940  -0.073731  0.014452  0.095087
# duration  -0.004399  0.001086  0.020308  -0.001404 -0.010179  0.018195
# campaign   0.003877 -0.002986 -0.028973  -0.004625  0.014234 -0.014147
# pdays     -0.022419  0.007885  0.019849  -0.004705 -0.029652  0.003968
# previous   0.000928 -0.010544  0.006556  -0.025336 -0.018825  0.017243
# poutcome   0.052004 -0.026480  0.022325  -0.075249 -0.021268  0.049263
# FDcreated  0.026939 -0.028155  0.045431  -0.069513 -0.020336  0.049705
#
#             housing      loan   contact       day     month  duration  \
# age       -0.186225 -0.015299  0.193826 -0.009880  0.091204 -0.004399
# job        0.069373  0.054872  0.015309 -0.000567 -0.041774  0.001086
# marital   -0.013138 -0.018112 -0.051503 -0.004975 -0.042940  0.020308
# education  0.078523  0.027624  0.112556 -0.025722 -0.073731 -0.001404
# default   -0.004906  0.076101 -0.018047  0.007432  0.014452 -0.010179
# balance   -0.067068 -0.083231  0.036429  0.003348  0.095087  0.018195
# housing    1.000000  0.039248 -0.054248 -0.028256 -0.173601  0.006088
# loan       0.039248  1.000000 -0.016331  0.009908  0.023176 -0.011781
# contact   -0.054248 -0.016331  1.000000  0.024829  0.005578 -0.030472
# day       -0.028256  0.009908  0.024829  1.000000  0.100077 -0.029674
# month     -0.173601  0.023176  0.005578  0.100077  1.000000 -0.010799
# duration   0.006088 -0.011781 -0.030472 -0.029674 -0.010799  1.000000
# campaign  -0.021760  0.010603  0.065156  0.162336  0.055266 -0.083061
# pdays      0.123508 -0.023490 -0.026655 -0.093166 -0.109217 -0.000478
# previous   0.037042 -0.011729  0.002168 -0.052083 -0.035636  0.002330
# poutcome  -0.281824 -0.104080  0.020872  0.016573  0.075417  0.108610
# FDcreated -0.136070 -0.068381 -0.010817 -0.026821  0.019125  0.395099
#
#            campaign     pdays  previous  poutcome  FDcreated
# age        0.003877 -0.022419  0.000928  0.052004   0.026939
# job       -0.002986  0.007885 -0.010544 -0.026480  -0.028155
# marital   -0.028973  0.019849  0.006556  0.022325   0.045431
# education -0.004625 -0.004705 -0.025336 -0.075249  -0.069513
# default    0.014234 -0.029652 -0.018825 -0.021268  -0.020336
# balance   -0.014147  0.003968  0.017243  0.049263   0.049705
# housing   -0.021760  0.123508  0.037042 -0.281824  -0.136070
# loan       0.010603 -0.023490 -0.011729 -0.104080  -0.068381
# contact    0.065156 -0.026655  0.002168  0.020872  -0.010817
# day        0.162336 -0.093166 -0.052083  0.016573  -0.026821
# month      0.055266 -0.109217 -0.035636  0.075417   0.019125
# duration  -0.083061 -0.000478  0.002330  0.108610   0.395099
# campaign   1.000000 -0.089042 -0.035162 -0.001317  -0.072085
# pdays     -0.089042  1.000000  0.461822 -0.236661   0.103665
# previous  -0.035162  0.461822  1.000000  0.041667   0.094567
# poutcome  -0.001317 -0.236661  0.041667  1.000000   0.419028
# FDcreated -0.072085  0.103665  0.094567  0.419028   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Increase the plot size by specifying figsize
fig, ax = plt.subplots(figsize=(15, 15))

# Create a heatmap
sns.heatmap(df.corr(),ax=ax, annot=True,linewidth=3 ,cmap="YlGn")

#plot title
plt.title("Correlation of Features", size=15, y=1)

# Show the plot
plt.show()

# %%
#Sorting correlation values in descending order by FDcreated attribute
df.corr()["FDcreated"].sort_values(ascending=False)
# Out:
# FDcreated    1.000000
# poutcome     0.419028
# duration     0.395099
# pdays        0.103665
# previous     0.094567
# balance      0.049705
# marital      0.045431
# age          0.026939
# month        0.019125
# contact     -0.010817
# default     -0.020336
# day         -0.026821
# job         -0.028155
# loan        -0.068381
# education   -0.069513
# campaign    -0.072085
# housing     -0.136070
# Name: FDcreated, dtype: float64

# %%
#Find outliers

fig, ax = plt.subplots(figsize=(10, 8))

# Create a box plot
df.plot.box(ax=ax)

# Set axis labels and ticks
plt.xticks(range(len(df.columns)), df.columns, rotation='vertical')

# Show the plot
plt.show()

# %%
#Drop unwanted columns
df.drop(columns=['contact','day', 'job','loan', 'education', 'campaign', 'housing', 'default'], axis = 'columns', inplace=True)

df
# Out:
#        age  marital   balance  month  duration     pdays  previous  poutcome  \
# 0       58        1  0.092259      5       261  0.000000         0       NaN
# 1       44        2  0.073067      5       151  0.000000         0       NaN
# 2       33        1  0.072822      5        76  0.000000         0       NaN
# 3       47        1  0.086476      5        92  0.000000         0       NaN
# 4       33        2  0.072812      5       198  0.000000         0       NaN
# ...    ...      ...       ...    ...       ...       ...       ...       ...
# 49727   33        1  0.069780      7       329  0.000000         0       NaN
# 49728   57        1  0.042725      5       153  0.000000         0       NaN
# 49729   57        1  0.075482      8       151  0.000000         0       NaN
# 49730   28        1  0.083126      2       129  0.243119         3       2.0
# 49731   44        2  0.083117      4       345  0.286697         7       2.0
#
#        FDcreated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 49727          0
# 49728          0
# 49729          0
# 49730          0
# 49731          0
#
# [49732 rows x 9 columns]

# %%
#drop NaN values
df = df.dropna()

df
# Out:
#        age  marital   balance  month  duration     pdays  previous  poutcome  \
# 24060   33        1  0.080811     10        39  0.174312         3       1.0
# 24062   42        2  0.070561     10       519  0.191514         1       2.0
# 24064   33        1  0.104071     10       144  0.105505         4       1.0
# 24072   36        1  0.094729     10        73  0.099771         4       2.0
# 24077   36        1  0.072803     10       140  0.165138         3       1.0
# ...    ...      ...       ...    ...       ...       ...       ...       ...
# 49703   32        2  0.075609      4       346  0.269495         3       1.0
# 49715   42        2  0.082609      5       951  0.425459         4       1.0
# 49725   38        1  0.083743      4        45  0.176606         1       1.0
# 49730   28        1  0.083126      2       129  0.243119         3       2.0
# 49731   44        2  0.083117      4       345  0.286697         7       2.0
#
#        FDcreated
# 24060          0
# 24062          1
# 24064          1
# 24072          0
# 24077          1
# ...          ...
# 49703          0
# 49715          1
# 49725          0
# 49730          0
# 49731          0
#
# [9068 rows x 9 columns]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# (1)Plot of the Created FD Account or not - Count

# %%
# Import Libraries
import matplotlib.pyplot as plt

# Count the occurrences of 1s and 0s in the 'FDcreated' column
fd_counts = df['FDcreated'].value_counts()

# Define custom colors for the bars
colors = ['#2843ed', '#f5222d']

# Create a bar plot with custom colors and labels
plt.bar(['FD Created (1)', 'Not Created (0)'], fd_counts.values, color=colors, label=['FD Created (1)', 'Not Created (0)'])

# Add labels to the bars
for i, count in enumerate(fd_counts):
    plt.text(i, count, f'{count}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Add labels and title
plt.xlabel('FD Created vs Not Created')
plt.ylabel('Count')
plt.title('Distribution of FD Creation')

# Add a legend
plt.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# (2)Compare the ages of customers who took fixed deposit and who didn’t

# %%
# import Libraries
import matplotlib.pyplot as plt

# Split the data into two groups: customers who took FD and those who didn't
fd_yes = df[df['FDcreated'] == 1]['age']
fd_no = df[df['FDcreated'] == 0]['age']

# Create a bar plot
plt.bar(['FD Taken', 'No FD Taken'], [fd_yes.mean(), fd_no.mean()], color=['#023d02', '#bfa006'])

# Add labels to the bars
plt.text(0, fd_yes.mean(), f'Mean Age: {fd_yes.mean():.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')
plt.text(1, fd_no.mean(), f'Mean Age: {fd_no.mean():.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Add labels and title
plt.xlabel('FD Taken vs No FD Taken')
plt.ylabel('Age')
plt.title('Comparison of Ages for FD Taken and Not Taken')

# Show the plot
plt.show()

# %% [markdown]
# (3)Compare the duration of customers who took fixed deposit and who didn’t

# %%
# imported Libraries
import matplotlib.pyplot as plt

# Assuming "df" is your DataFrame
df_yes_fd = df[df['FDcreated'] == 1]  # Selecting rows where FD was created
df_no_fd = df[df['FDcreated'] == 0]   # Selecting rows where FD was not created

# Scatter plot for customers who took fixed deposit
plt.scatter(df_yes_fd['duration'], df_yes_fd['FDcreated'], color='#66025e', label='Took FD')

# Scatter plot for customers who didn't take fixed deposit
plt.scatter(df_no_fd['duration'], df_no_fd['FDcreated'], color='#006341', label="Didn't take FD")

# Set labels and title
plt.xlabel('Duration')
plt.ylabel('FD Created (1) or Not (0)')
plt.title('Comparison of Duration for Customers')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# (4) Compare marital status column with FDcreated column

# %%
import matplotlib.pyplot as plt
import seaborn as sns

graphs = ['marital']

# Count the occurrences of 1s and 0s in the 'FDcreated' column
y = df['FDcreated']
y = y.values

for i in graphs:
    sns.countplot(x=i, hue=y, data=df, palette=sns.color_palette('bright'))
    plt.show()

# %% [markdown]
# (5) Plot a pie chart to show the fractions of customers who recieved calls in different months

# %%
import matplotlib.pyplot as plt

# Define a mapping dictionary from month numbers to month names
month_mapping = {
    1: 'jan', 
    2: 'feb', 
    3: 'mar', 
    4: 'apr', 
    5: 'may', 
    6: 'jun', 
    7: 'jul', 
    8: 'aug', 
    9: 'sept', 
    10: 'oct', 
    11: 'nov', 
    12: 'dec'
}

# Group the data by 'month' and count the number of customers recieved calls for each month
month_counts = df[df['FDcreated'] == 1]['month'].map(month_mapping).value_counts()

# Create a pie chart
plt.figure(figsize=(10, 6))
plt.pie(month_counts, labels=month_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(month_counts))))

# Add a title
plt.title('Distribution of Customers who recieved calls in each month')

# Display the pie chart
plt.show()

# %% [markdown]
# # Model Training

# %%
#divide dataset into independent and dependent variables
X = df.iloc[:,:-1].values 
y = df.iloc[:,-1].values

# %%
#save dataset in new csv file
df.to_csv('df.csv', index=False)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# Decision Tree classifier

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error
import pickle
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming X_train and y_train are your training data
# and X_test and y_test are your test data

# Create a decision tree classifier
dt = DecisionTreeClassifier(criterion='entropy', max_depth=3)

# Fit the decision tree classifier to the training data
dt.fit(X_train, y_train)

# Make predictions on the test data
y_pred = dt.predict(X_test)

# Evaluate the predictions
conf_matrix = confusion_matrix(y_test, y_pred)

# Create a heatmap
print("Heap Map:\n")

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds_r', cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
print()
print()

# Create classification Report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)

# Calculate training error
dt_train_pred = dt.predict(X_train)
mse_train = mean_squared_error(y_train, dt_train_pred)
train_accuracy = 1 - mse_train

# Calculate testing error
dt_test_pred = dt.predict(X_test)
mse_test = mean_squared_error(y_test, dt_test_pred)
test_accuracy = 1 - mse_test

print("Training Error of Decision Tree Model:", mse_train)
print("Testing Error of Decision Tree Model:", mse_test)

print()

print("Training Accuracy of Decision Tree Model:", train_accuracy)
print("Testing Accuracy of Decision Tree Model:", test_accuracy)

# Plotting training and testing accuracy
labels = ['Training Accuracy', 'Testing Accuracy']
values = [train_accuracy, test_accuracy]

fig, ax = plt.subplots()
bars = ax.bar(labels, values, color=['red', 'black'])

# # Adding the numerical values on top of the bars
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), va='bottom' if yval < 0.5 else 'top', ha='center', color='white', weight='bold')

plt.title('Training and Testing Accuracy of Decision Tree Classifier')
plt.show()

# # Create a pickle file for the model
dt_model_pickle = open('decision_tree_model.pkl', 'wb')
pickle.dump(dt, dt_model_pickle)
dt_model_pickle.close()
# Out:
# Heap Map:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      1764
#            1       0.68      0.48      0.56       503
#
#     accuracy                           0.83      2267
#    macro avg       0.77      0.71      0.73      2267
# weighted avg       0.82      0.83      0.82      2267
#
# Training Error of Decision Tree Model: 0.15997647404793414
# Testing Error of Decision Tree Model: 0.1658579620644023
#
# Training Accuracy of Decision Tree Model: 0.8400235259520659
# Testing Accuracy of Decision Tree Model: 0.8341420379355977

# %% [markdown]
# KNeighbors Classifier

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error
import pickle
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming X_train and y_train are your training data
# and X_test and y_test are your test data

# Create a KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the KNN classifier to the training data
knn.fit(X_train, y_train)

# Make predictions on the test data
y_pred = knn.predict(X_test)

# Evaluate the predictions
conf_matrix = confusion_matrix(y_test, y_pred)
# Create a heatmap
print("Heap Map:\n")

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples_r', cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

print()
print()

# Create classification Report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)

# Calculate training error
knn_train_pred = knn.predict(X_train)
mse_train = mean_squared_error(y_train, knn_train_pred)
train_accuracy = 1 - mse_train

# Calculate testing error
knn_test_pred = knn.predict(X_test)
mse_test = mean_squared_error(y_test, knn_test_pred)
test_accuracy = 1 - mse_test

print("Training Error of KNN Model:", mse_train)
print("Testing Error of KNN Model:", mse_test)

print()

print("Training Accuracy of KNN Model:", train_accuracy)
print("Testing Accuracy of KNN Model:", test_accuracy)

# Plotting training and testing accuracy
labels = ['Training Accuracy', 'Testing Accuracy']
values = [train_accuracy, test_accuracy]

fig, ax = plt.subplots()
bars = ax.bar(labels, values, color=['purple', 'pink'])

# # Adding the numerical values on top of the bars
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), va='bottom' if yval < 0.5 else 'top', ha='center', color='white', weight='bold')

plt.title('Training and Testing Accuracy of KNN Model')
plt.show()

# # Create a pickle file for the model
knn_model_pickle = open('knn_model.pkl', 'wb')
pickle.dump(knn, knn_model_pickle)
knn_model_pickle.close()
# Out:
# Heap Map:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1764
#            1       0.50      0.34      0.40       503
#
#     accuracy                           0.78      2267
#    macro avg       0.66      0.62      0.63      2267
# weighted avg       0.75      0.78      0.76      2267
#
# Training Error of KNN Model: 0.16071166004999266
# Testing Error of KNN Model: 0.2218791354212616
#
# Training Accuracy of KNN Model: 0.8392883399500073
# Testing Accuracy of KNN Model: 0.7781208645787384

# %% [markdown]
# Linear Regression Model

# %%
# Import Libraries
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, classification_report, confusion_matrix
import pickle
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score
import seaborn as sns

# %%
# Assuming y_train and y_test are your target variables for regression
threshold = 0.5

# %%
# Convert regression to classification
y_train_class = np.where(y_train > threshold, 1, 0)
y_test_class = np.where(y_test > threshold, 1, 0)

# %%
# Create the LinearRegression model
reg = LinearRegression()

# %%
# Train the model
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
reg_pred = reg.predict(X_test)

# %%
# Convert regression predictions to classification
reg_pred_class = np.where(reg_pred > threshold, 1, 0)

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test_class, reg_pred_class)

print("Confusion Matrix:\n")
print(conf_matrix)
# Out:
# Confusion Matrix:
#
# [[1644  120]
#  [ 264  239]]

# %%
# Create a heatmap
print("Heat Map:\n")

fig, ax = plt.subplots(figsize=(5, 4))

# Define the descriptions corresponding to each cell
descriptions = []

for i in range(len(conf_matrix)):
    row_descriptions = []
    for j in range(len(conf_matrix)):
        row_descriptions.append(f"\n\n\nA-{['No','Yes'][i]}, P-{['No','Yes'][j]}")
    descriptions.append(row_descriptions)

# Create the heatmap with annotations
heatmap = sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues_r', cbar=False)

# Adding descriptions
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix)):
        description = descriptions[i][j]
        plt.text(j + 0.5, i + 0.5, f"{description}", ha='center', va='center', color='black', fontsize=10)

cbar = ax.figure.colorbar(heatmap.collections[0])
cbar.set_label('Count', rotation=270, labelpad=15)

plt.title("Confusion Matrix")
plt.xlabel("Predicted(P)")
plt.ylabel("Actual(A)")
plt.show()
# Out:
# Heat Map:

# %%
# Create clasification Report
classification_rep = classification_report(y_test_class, reg_pred_class)

print("Clasification Report:\n")
print(classification_rep)
# Out:
# Clasification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.90      1764
#            1       0.67      0.48      0.55       503
#
#     accuracy                           0.83      2267
#    macro avg       0.76      0.70      0.72      2267
# weighted avg       0.82      0.83      0.82      2267

# %%
# Evaluate the model for regression (using Mean Squared Error)
mse = mean_squared_error(y_test, reg_pred)

# Compute training accuracy and error
reg_train_pred = reg.predict(X_train)
mse_train = mean_squared_error(y_train, reg_train_pred)
train_accuracy = 1 - mse_train

# Calculate testing accuracy
lr_acc = 1 - mse


# Print evaluation metrics

print("Error of Training and Testing data:\n")
print("Mean Squared Error (MSE) on Training Set of Linear Regression Model:", mse_train)
print("Mean Squared Error (MSE) on Testing Set of Linear Regression Model:", mse)

print()

print("Accuracy of Training and Testing data:\n")
print("Training Accuracy of Linear Regression Model Classifier:", train_accuracy)
print("Testing Accuracy of Linear Regression Model Classifier:", lr_acc)
# Out:
# Error of Training and Testing data:
#
# Mean Squared Error (MSE) on Training Set of Linear Regression Model: 0.1278417258546459
# Mean Squared Error (MSE) on Testing Set of Linear Regression Model: 0.13137996307655156
#
# Accuracy of Training and Testing data:
#
# Training Accuracy of Linear Regression Model Classifier: 0.8721582741453541
# Testing Accuracy of Linear Regression Model Classifier: 0.8686200369234485

# %%
# plot of training and testing accuracy
print("Plot of Training and Testing Accuracy:")


# Plotting training and testing accuracy
labels = ['Training Accuracy', 'Testing Accuracy']
values = [train_accuracy, lr_acc]

fig, ax = plt.subplots()
bars = ax.bar(labels, values, color=['#070b2e', '#13422f'])

# Adding the numerical values on top of the bars
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), va='bottom' if yval < 0.5 else 'top', ha='center', color='white', weight='bold')

plt.title('Training and Testing Accuracy of Linear Regression Model')
plt.show()
# Out:
# Plot of Training and Testing Accuracy:

# %%
# Create a pickle file for the linear regression model
linear_regression_pickle = open('linear_regression_model.pkl', 'wb')
pickle.dump(reg, linear_regression_pickle)
linear_regression_pickle.close()

# %% [markdown]
# Support Vector Machine

# %%
# Import Libraries
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error
import pickle
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# Assuming y_train and y_test are your target variables for regression
threshold = 0.5

# %%
# Convert regression to classification
y_train_class = np.where(y_train > threshold, 1, 0)
y_test_class = np.where(y_test > threshold, 1, 0)

# %%
# Create the SVM model
svm = SVC()

# %%
# Train the model
svm.fit(X_train, y_train_class)
# Out:
# SVC()

# %%
# Make predictions on the test set
svm_pred_class = svm.predict(X_test)

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test_class, svm_pred_class)

print("Confusion Matrix:\n")
print(conf_matrix)
# Out:
# Confusion Matrix:
#
# [[1707   57]
#  [ 430   73]]

# %%
# Create a heatmap
print("Heat Map:\n")

fig, ax = plt.subplots(figsize=(5, 4))

# Define the descriptions corresponding to each cell
descriptions = []

for i in range(len(conf_matrix)):
    row_descriptions = []
    for j in range(len(conf_matrix)):
        row_descriptions.append(f"\n\n\nA-{['No','Yes'][i]}, P-{['No','Yes'][j]}")
    descriptions.append(row_descriptions)

# Create the heatmap with annotations
heatmap = sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='RdPu', cbar=False)

# Adding descriptions
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix)):
        description = descriptions[i][j]
        plt.text(j + 0.5, i + 0.5, f"{description}", ha='center', va='center', color='black', fontsize=10)

cbar = ax.figure.colorbar(heatmap.collections[0])
cbar.set_label('Count', rotation=270, labelpad=15)

plt.title("Confusion Matrix")
plt.xlabel("Predicted(P)")
plt.ylabel("Actual(A)")
plt.show()
# Out:
# Heat Map:

# %%
# Create classification Report

print("Clasification Report:\n")
classification_rep = classification_report(y_test_class, svm_pred_class)

print(classification_rep)
# Out:
# Clasification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88      1764
#            1       0.56      0.15      0.23       503
#
#     accuracy                           0.79      2267
#    macro avg       0.68      0.56      0.55      2267
# weighted avg       0.75      0.79      0.73      2267

# %%
# Calculate training error
svm_train_pred = svm.predict(X_train)
mse_train = mean_squared_error(y_train_class, svm_train_pred)
train_accuracy = 1 - mse_train

# Calculate testing error
svm_test_pred = svm.predict(X_test)
mse_test = mean_squared_error(y_test_class, svm_test_pred)
test_accuracy = 1 - mse_test

print("Error of Training and Testing data:\n")
print("Training Error of SVM Model:", mse_train)
print("Testing Error of SVM Model:", mse_test)

print()

print("Accuracy of Training and Testing data:\n")
print("Training Accuracy of SVM Model:", train_accuracy)
print("Testing Accuracy of SVM Model:", test_accuracy)
# Out:
# Error of Training and Testing data:
#
# Training Error of SVM Model: 0.2226143214233201
# Testing Error of SVM Model: 0.21482134980149978
#
# Accuracy of Training and Testing data:
#
# Training Accuracy of SVM Model: 0.77738567857668
# Testing Accuracy of SVM Model: 0.7851786501985002

# %%
# plot training and testing accuracy
print("Plot of Training and Testing Accuracy:")

# Plotting training and testing accuracy
labels = ['Training Accuracy', 'Testing Accuracy']
values = [train_accuracy, test_accuracy]

fig, ax = plt.subplots()
bars = ax.bar(labels, values, color=['#d90ba9', '#350254'])

# Adding the numerical values on top of the bars
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), va='bottom' if yval < 0.5 else 'top', ha='center', color='white', weight='bold')

plt.title('Training and Testing Accuracy of Support Vector Machine')
plt.show()
# Out:
# Plot of Training and Testing Accuracy:

# %%
# Create a pickle file for the svm model
svm_model_pickle = open('svm_model.pkl', 'wb')
pickle.dump(svm, svm_model_pickle)
svm_model_pickle.close()
